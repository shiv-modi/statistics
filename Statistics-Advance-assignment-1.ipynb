# %% [markdown]
# Statistics Advance Assignment

# %% [markdown]
# Q1. What is the Probability density function?

# %% [markdown]
# It specify the distribution of a continuos random variable.

# %% [markdown]
# Q2. What are the types of Probability distribution?

# %% [markdown]
#  types of Probability distribution are :
#
#         Bernoulli Distribution
#         Normal Distribution
#         Poisson Distribution
#         Binomial Distribution
#         Uniform Distribution

# %% [markdown]
# Q3. Write a Python function to calculate the probability density function of a normal distribution with
# given mean and standard deviation at a given point.

# %%
from scipy.stats import norm
import numpy as np
data_start = -5
data_end = 5
data_point = 11

data = np.linspace(data_start,data_end,data_point)
mean = np.mean(data)
std = np.std(data)

n_d = norm.pdf(5,loc=mean,scale=std)


n_d
# Out:
# 0.03614447853363626

# %% [markdown]
# Q4. What are the properties of Binomial distribution? Give two examples of events where binomial
# distribution can be applied.

# %% [markdown]
# 1) Discreate random variables
# 2) Every Experiment outcome is binsary
# 3) this Experiment has N number of trials
#
#
#
# Example :
# 1) tossing a coin
# 2) lottery price chances to get or not

# %% [markdown]
# Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4
# and plot a histogram of the results using matplotlib.

# %%
from scipy.stats import binom
import numpy as np
import matplotlib.pyplot as plt


n = np.random.randint(1,1000)
p = 0.4
k = list(range(n + 1))

mean , variance = binom.stats(n , p)

dist = [binom.pmf(i,n,p) for i in k]

print("r\tp(r)")
for i in range(n + 1):
    
    print(str(k[i]) + "\t" + str(dist[i]))
    
plt.bar(k, dist) 
plt.show()
# Out:
# r	p(r)
# 0	7.394334140235132e-187
# 1	4.1358975624385467e-184
# 2	1.1552940524411352e-181
# 3	2.148846937540259e-179
# 4	2.994060066306429e-177
# 5	3.3333868738209295e-175
# 6	3.08893850307437e-173
# 7	2.4505578791055163e-171
# 8	1.6990534628463542e-169
# 9	1.0458617982410836e-167
# 10	5.787101950266953e-166
# 11	2.9075803131948335e-164
# 12	1.3374869440695789e-162
# 13	5.6723164243360385e-161
# 14	2.2311111269055478e-159
# 15	8.180740798653704e-158
# 16	2.8087210075379393e-156
# 17	9.06500936942666e-155
# 18	2.7597917413586047e-153
# 19	7.950136911072156e-152
# 20	2.1730374223595792e-150
# 21	5.649897298134658e-149
# 22	1.4004896939013806e-147
# 23	3.3165219707751327e-146
# 24	7.517449800423603e-145
# 25	1.6337924232919231e-143
# 26	3.41001803220451e-142
# 27	6.845295457240045e-141
# 28	1.3234237883996516e-139
# 29	2.467348718142897e-138
# 30	4.441227692657057e-137
# 31	7.726781082493385e-136
# 32	1.3006748155532072e-134
# 33	2.120494093235089e-133
# 34	3.351212233622754e-132
# ...

# %% [markdown]
# Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution
# with given mean at a given point.

# %%
import math

def poisson_cdf(k, mean):
    if k < 0:
        return 0.0  
    cdf = 0.0
    for i in range(k + 1):
        cdf += (math.exp(-mean) * mean**i) / math.factorial(i)
    return cdf

mean = 5.0  
point = 3   
cdf = poisson_cdf(point, mean)
print(f"The CDF at k={point} with mean {mean} is {cdf:.4f}")
# Out:
# The CDF at k=3 with mean 5.0 is 0.2650

# %% [markdown]
# Q7. How Binomial distribution different from Poisson distribution?

# %% [markdown]
# Binomial and Poisson both are pmf function in binomial distribution every experiment outcome is binary and every experiment has n number of trials.while in poisson distribution it has a fixed number of time interval where every time interval how many many outcome are occur for example : every hour how many patient are coming.

# %% [markdown]
# Q8. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the
# sample mean and variance.

# %%
import numpy as np

# %%
mean = 5
sample_size = 1000

sample = poisson_sample = np.random.poisson(mean,sample_size)
np.mean(sample)
np.var(sample)
# Out:
# 4.739375

# %% [markdown]
# Q9. How mean and variance are related in Binomial distribution and Poisson distribution?

# %% [markdown]
# In a binomial distribution, there are only two possible outcomes, i.e. success or failure. Conversely, there are an unlimited number of possible outcomes in the case of poisson distribution.

# %% [markdown]
# Q10. In normal distribution with respect to mean position, where does the least frequent data appear?

# %% [markdown]
# In a normal distribution, the data is most concentrated around the mean, and it gradually becomes less frequent as you move away from the mean in both directions.
